# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
c = pd.read_csv('cces_example_data.csv')
c.head(10)
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
# 5             4            6    1     3         2   87           9     3
# 6             2            3    1     6         1   83          11     3
# 7             1            1    1     5         1   69          11     3
# 8             1            2    1     6         1   84          10     3
# 9             3            4    2     4         1   63           8     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# ...

# %%
fig1, ax1 = plt.subplots(1, 2)
ax1[0].set_title('Age Histogram')
ax1[1].set_title('Political Identity')
plt.show()

# %%
c.groupby('Evaluation').count()
# Out:
#             pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  \
# Evaluation
# 0                    365          365  365   365       365  365         365
# 1                     48           48   48    48        48   48          48
# 2                    202          202  202   202       202  202         202
# 3                     44           44   44    44        44   44          44
#
#             pid3  ideo5  QueerPhobia  ImmiPhobia  InterGBiasParty  \
# Evaluation
# 0            365    365          365         365              365
# 1             48     48           48          48               48
# 2            202    202          202         202              202
# 3             44     44           44          44               44
#
#             InterGBiasCand  InterGBiasSup  LibMediaUse  ConMediaUse  \
# Evaluation
# 0                      365            365          365          365
# 1                       48             48           48           48
# ...

# %%
c.groupby('Evaluation').describe()
# Out:
#            pew_religimp                                               \
#                   count      mean       std  min  25%  50%  75%  max
# Evaluation
# 0                 365.0  2.652055  1.196160  1.0  2.0  3.0  4.0  4.0
# 1                  48.0  2.041667  1.051004  1.0  1.0  2.0  3.0  4.0
# 2                 202.0  1.970297  1.092311  1.0  1.0  2.0  3.0  4.0
# 3                  44.0  1.818182  1.017812  1.0  1.0  1.5  2.0  4.0
#
#            pew_churatd            ... teamweight           caseid  \
#                  count      mean  ...        75%       max  count
# Evaluation                        ...
# 0                365.0  4.583562  ...   0.955207  6.474958  365.0
# 1                 48.0  4.020833  ...   1.180290  6.474958   48.0
# 2                202.0  3.970297  ...   1.189193  3.958211  202.0
# 3                 44.0  3.681818  ...   1.082289  3.628362   44.0
#
#                                                                     \
# ...

# %%
c.groupby('Evaluation').count()
# Out:
#             pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  \
# Evaluation
# 0                    365          365  365   365       365  365         365
# 1                     48           48   48    48        48   48          48
# 2                    202          202  202   202       202  202         202
# 3                     44           44   44    44        44   44          44
#
#             pid3  ideo5  QueerPhobia  ImmiPhobia  InterGBiasParty  \
# Evaluation
# 0            365    365          365         365              365
# 1             48     48           48          48               48
# 2            202    202          202         202              202
# 3             44     44           44          44               44
#
#             InterGBiasCand  InterGBiasSup  LibMediaUse  ConMediaUse  \
# Evaluation
# 0                      365            365          365          365
# 1                       48             48           48           48
# ...

# %%
c.groupby('Evaluation').count()
# Out:
#             pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  \
# Evaluation
# 0                    365          365  365   365       365  365         365
# 1                     48           48   48    48        48   48          48
# 2                    202          202  202   202       202  202         202
# 3                     44           44   44    44        44   44          44
#
#             pid3  ideo5  QueerPhobia  ImmiPhobia  InterGBiasParty  \
# Evaluation
# 0            365    365          365         365              365
# 1             48     48           48          48               48
# 2            202    202          202         202              202
# 3             44     44           44          44               44
#
#             InterGBiasCand  InterGBiasSup  LibMediaUse  ConMediaUse  \
# Evaluation
# 0                      365            365          365          365
# 1                       48             48           48           48
# ...

# %% [markdown]
# I noticed that all the columns hold the same value, so I went aheaf with comparing Evaluation and Sex

# %%
c.groupby('Evaluation')['sex'].count()
# Out:
# Evaluation
# 0    365
# 1     48
# 2    202
# 3     44
# Name: sex, dtype: int64

# %% [markdown]
# The following is me trying to figure out the solution without looking at class notes, big mistake. The solution is on line 87.

# %%
x = c['Evaluation']
y = c['sex']

plt.bar(x, y)

plt.title("Evaluation Frequency")

plt.ylabel('Frequency')

plt.xlabel('Evaluation')

plt.show()

# %% [markdown]
# fig2, ax2 = plt.subplots()
# ax1.bar(x = c['Evaluation'], y = c['sex'])
# plt.show()

# %% [markdown]
# comm[comm['Vehicle'] == ' Passat']
#
#
# passat = comm[comm['Vehicle'] == 'Passat']
# st = comm[comm['Vehicle'] == 'Street Triple']
#
# fig2, ax2 = plt.subplots()
# ax2.scatter(x = comm['TripID'], y = comm['CommuteTime'], marker = 4)
# ax2.scatter(x = st['TripID'], y = st['CommuteTime'], marker = 1)
#
# plt.show()

# %%
eval = c[c['Evaluation'] == 'Evaluation']
freq = c[c['sex'] == 'sex']

fig2, ax2 = plt.subplots()
ax2.scatter(x = c['Evaluation'], y = c['sex'])

plt.show()

# %%
plt.bar(x = c['Evaluation'], height = c['sex'])
# Out:
# <BarContainer object of 659 artists>

# %%
Eval = c.groupby('Evaluation')['sex'].count()
Eval.index
# Out:
# Index([0, 1, 2, 3], dtype='int64', name='Evaluation')

# %% [markdown]
# I forgot to look at the class notes earlier, thankfully I did because that led to the following

# %%
fig2, ax2 = plt.subplots()
ax3.bar(x = Eval.index, height = Eval)
plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(x = c['ConMediaUse'], y = c['ImmiPhobia'])
plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(x = c['ImmiPhobia'], y = c['ConMediaUse'])
plt.show()

# %% [markdown]
# A suggestion I would have for the above graph would be to delve into something density related like countour lines (https://clauswilke.com/dataviz/overlapping-points.html). It's interesting to see the uniformity of the dots, but what's more interesting is the gap areas that can be exposed. I feel like the data is too linear and not the best option for a scatter style. I tried a few variations but the data seems very stacked. When we talk about the scatter plot, I tried to look through more and more stuff, but I wasn't able to come up with anything significant. Would love to learn about it in the next class!
